# %% [markdown]
# # Data Visualisation of the Pokemon dataset
#
# This project focuses on taking information from a Pokemon dataset with and all relevant data about their weaknesses, stats, height, weight, etc. With a large amount of domain expertise on Pokemon, I started off by simply looking at the data and trying to think of what interesting information I could pull from it.
#
# We start off by simply importing the packages needed for data analysis in Python, such as Pandas, Matplotlib, Seaborn to get the csv file and visualise it.

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')

# %matplotlib inline

# %% [markdown]
# After importing the files, we need to read the csv file and store it into a variable.

# %%
df=pd.read_csv("Pokemon_data.csv")
df_mega=pd.read_csv("Pokemon_data.csv")
df.head()
# Out:
#    pokedex_number           name  generation   classfication  \
# 0               1      Bulbasaur           1    Seed Pokémon
# 1               2        Ivysaur           1    Seed Pokémon
# 2               3       Venusaur           1    Seed Pokémon
# 3               3  Mega Venusaur           1    Seed Pokémon
# 4               4     Charmander           1  Lizard Pokémon
#
#                      abilities  height_m  weight_kg  type1   type2  \
# 0  ['Overgrow', 'Chlorophyll']       0.7        6.9  Grass  Poison
# 1  ['Overgrow', 'Chlorophyll']       1.0       13.0  Grass  Poison
# 2  ['Overgrow', 'Chlorophyll']       2.0      100.0  Grass  Poison
# 3                ['Thick Fat']       2.4      155.5  Grass  Poison
# 4     ['Blaze', 'Solar Power']       0.6        8.5   Fire    None
#
#    base_total  ...  against_psychic  against_rock  against_steel  \
# 0         318  ...              2.0           1.0            1.0
# ...

# %% [markdown]
# After reading the file, we analyse the dataframe to check for any missing values. We use describe and info functions to get the information of the dataset.

# %%
df.describe()
# Out:
#        pokedex_number   generation     height_m    weight_kg   base_total  \
# count     1013.000000  1013.000000  1013.000000  1013.000000  1013.000000
# mean       436.574531     4.025666     1.279961    70.497137   437.084896
# std        258.802723     2.231940     1.401779   129.941006   120.156916
# min          1.000000     1.000000     0.100000     0.100000   175.000000
# 25%        214.000000     2.000000     0.600000     9.000000   330.000000
# 50%        432.000000     4.000000     1.000000    29.000000   455.000000
# 75%        659.000000     6.000000     1.500000    70.500000   514.000000
# max        890.000000     8.000000    20.000000   999.900000   780.000000
#
#                 hp       attack      defense    sp_attack   sp_defense  ...  \
# count  1013.000000  1013.000000  1013.000000  1013.000000  1013.000000  ...
# mean     69.595262    80.076012    74.252715    72.772952    71.968411  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1013 entries, 0 to 1012
# Data columns (total 40 columns):
# pokedex_number      1013 non-null int64
# name                1013 non-null object
# generation          1013 non-null int64
# classfication       1013 non-null object
# abilities           1013 non-null object
# height_m            1013 non-null float64
# weight_kg           1013 non-null float64
# type1               1013 non-null object
# type2               1013 non-null object
# base_total          1013 non-null int64
# hp                  1013 non-null int64
# attack              1013 non-null int64
# defense             1013 non-null int64
# sp_attack           1013 non-null int64
# sp_defense          1013 non-null int64
# speed               1013 non-null int64
# against_bug         1013 non-null float64
# against_dark        1013 non-null float64
# against_dragon      1013 non-null float64
# against_electric    1013 non-null float64
# ...

# %% [markdown]
# Now we check for any columns with missing values.If there are any missing values, we need to replace them with something else because we can not get any insights out of empty values. Luckily, there are no column with null values.

# %%
missing_cols=df.columns[df.isna().any()].tolist()
missing_cols
# Out:
# []

# %% [markdown]
# Now we remove all the mega evolutions from one of the dataset while keeping the other dataset intact. This is done because mega evolutions are basically the same pokemon. So the mega evolution will only act as a duplicate values in some of the analysis. For example, when we count the total number of psychic pokemon, mewtwo's both mega evolutions will be counted as well in the total number of psychics. So to deal with this, we have kept one dataframe where there are no mega forms.

# %%
mega = []
for i, row in df.iterrows():
  if(row.is_mega==1):
    mega.append(i)
df.drop(df.index[mega], inplace=True)

# %%
df.describe()
# Out:
#        pokedex_number  generation    height_m   weight_kg  base_total  \
# count      967.000000  967.000000  967.000000  967.000000  967.000000
# mean       445.077559    4.100310    1.238263   67.427404  428.598759
# std        259.637439    2.242371    1.361526  126.323896  115.389987
# min          1.000000    1.000000    0.100000    0.100000  175.000000
# 25%        219.500000    2.000000    0.500000    8.500000  325.000000
# 50%        449.000000    4.000000    1.000000   28.000000  450.000000
# 75%        669.500000    6.000000    1.500000   66.050000  505.000000
# max        890.000000    8.000000   20.000000  999.900000  770.000000
#
#                hp      attack     defense   sp_attack  sp_defense  ...  \
# count  967.000000  967.000000  967.000000  967.000000  967.000000  ...
# mean    69.231644   77.955533   72.748707   70.802482   70.681489  ...
# std     26.204802   30.844885   29.714479   30.807041   27.367068  ...
# ...

# %% [markdown]
# Now is the time to do the first analysis. We need to find how many pokemon have a secondary typing. To do this, we count the numbe of dual type pokemon by iterating through type2 column of the dataframe. This will tell us if the pokemon has secondary type or not.

# %%
single_type=0
dual_type=0
for i in df.index:
    if df["type2"][i]=="None":
        single_type+=1
    else:
        dual_type+=1
print("Number of single type pokemon are {s} and the number of dual type pokemon are {d}".format(s=single_type, d=dual_type))
print()
# Out:
# Number of single type pokemon are 473 and the number of dual type pokemon are 494

# %% [markdown]
# Now let's make a pie chart so that we can visualise our result for a better understanding.

# %%
labels="single type", "dual type"
sizes=[single_type, dual_type]
explode=(0,0.1)
plt.pie(sizes, labels=labels, explode=explode,autopct='%1.1f%%',shadow=True,
        startangle=270)
plt.axis('equal')
plt.title('Dual vs Single type Pokemon')
plt.tight_layout()
plt.show()
print("")

# %% [markdown]
# Now that we know the number and percentage of pokemon with a secondary type, we should check which type is most common primary type. We will do this by making a seaborn graph.

# %%
ind_count = pd.value_counts(df['type1'])

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("whitegrid")

ax = sns.barplot(x=ind_count.index, y=ind_count, data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, fontsize = 12)
ax.set(xlabel='Primary types', ylabel='Count')
ax.set_title('Distribution of Primary Pokemon type')
# Out:
# Text(0.5, 1.0, 'Distribution of Primary Pokemon type')

# %% [markdown]
# Now we can see that water type is the most common primary type followed by normal, grass and bug type. This was kind of surprising for me because I thought normal type was the most common type. And flying is the most uncommon primary type. This surprised me too.
#
# Now let's so the same for the secondary typing and see the result.

# %%
ind_count=pd.value_counts(df['type2'])
ind_count=ind_count.drop("None")

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("whitegrid")

ax = sns.barplot(x=ind_count.index, y=ind_count, data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, fontsize = 12)
ax.set(xlabel='Secondary types', ylabel='Count')
ax.set_title('Distribution of Secondary Pokemon type')
# Out:
# Text(0.5, 1.0, 'Distribution of Secondary Pokemon type')

# %%
type1=pd.value_counts(df['type1'])
type2=ind_count=pd.value_counts(df['type2'])
overall=type1+type2
overall=overall.drop("None")
overall=overall.sort_values(ascending=False)

fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("whitegrid")

ax = sns.barplot(x=overall.index, y=overall, data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation = 45, fontsize = 12)
ax.set(xlabel='Overall', ylabel='Count')
ax.set_title('Distribution of Pokemon type(including primary and secondary)')
# Out:
# Text(0.5, 1.0, 'Distribution of Pokemon type(including primary and secondary)')

# %% [markdown]
# Now the fact that flying was most uncommon type doesn't seem so surprising. All the first route bird pokemon have the typing of normal/flying. This means the flying type is a common secondary typing, not a primary type.
#
# Now let us see what are the most common type combinations.

# %%
plt.subplots(figsize=(10, 10))

sns.heatmap(
    df[df['type2']!='None'].groupby(['type1', 'type2']).size().unstack(),
    linewidths=1,
    annot=True,
    cmap="Blues"
)

plt.xticks(rotation=35)
plt.show()

# %% [markdown]
# The most common combination is normal/flying. This can be easily interpreted because every game has atleast one primary route bird which generally have this typing. So this is the most common combination. It is then followed by grass/poison and bug/flying.
#
# Now let's see the relation between Base stat total and the catch rate of pokemon. The higher the base stat total, the stronger the pokemon will be and the higher the catch rate, the easier it will be for us to catch it in a single throw.
# I assume that the higher the base stat total will be, the lower should be the catch rate.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
sns.set_style("white")
X=df['base_total']
Y=df["capture_rate"]
ax = sns.scatterplot(x=X, y=Y, data=df,
                     hue=df['is_legendary'], alpha=.9, palette="muted")
ax.set(xlabel='Base stats total', ylabel='Catch rate')
ax.set_title('Relationship between Base stats total and Catch rate')
# Out:
# Text(0.5, 1.0, 'Relationship between Base stats total and Catch rate')

# %%
fig, ax = plt.subplots()
fig.set_size_inches(15, 10)
sns.set_style("white")
X=df['base_total']
Y=df["capture_rate"]
ax = sns.scatterplot(x=X, y=Y, data=df,
                     hue=df['is_mythical'], alpha=.9, palette="muted")
ax.set(xlabel='Base stats total', ylabel='Catch rate')
ax.set_title('Relationship between Base stats total and Catch rate')
# Out:
# Text(0.5, 1.0, 'Relationship between Base stats total and Catch rate')

# %% [markdown]
# There are two scatter plots showing to us the Relationship between Base stats total and Catch rate. Each of the graph is highlighted with is_legendary and is_mythical so that we can compare the realtionship and see where the mythical and legendary pokemon stand in this list. We see that the was an inverse relationship between the bst and catch rate. This means that the stronger the pokemon, the harder it will be for us to catch it. Also, mythical and legendary pokemon usually have very low catch rates.
#
# Now let's check if there is any relation between height and weight of a pokemon.

# %%
df_mega['height_m']=pd.to_numeric(df_mega['height_m'])
df_mega['weight_kg']=pd.to_numeric(df_mega['weight_kg'])
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")
X=df['height_m']
Y=df['weight_kg']
ax = sns.scatterplot(x=X, y=Y, data=df,
                     alpha=.6, palette="muted")
ax.set(xlabel='Height in meters', ylabel='weigth in kg')
ax.set_title('Relationship between Height and Weight')
# Out:
# Text(0.5, 1.0, 'Relationship between Height and Weight')

# %% [markdown]
# Now we can see that most of the pokemon lie in a range of height and weight ratio and the height increases with weight.
#
# Now we should find the heaviest and the biggest pokemon.

# %%
print("The tallest pokemon are:")
tall=df_mega['name'][df_mega['height_m']>9].tolist()
for i in tall:
    print(i)

print("\nThe heaviest pokemon are:")
heavy=df_mega['name'][df_mega['weight_kg']>900].tolist()
for i in heavy:
    print(i)
# Out:
# The tallest pokemon are:
# Alolan Exeggutor
# Steelix
# Mega Steelix
# Wailord
# Primal Kyogre
# Mega Rayquaza
# Celesteela
# Eternatus
#
# The heaviest pokemon are:
# Mega Metagross
# Groudon
# Primal Groudon
# Mudsdale
# Cosmoem
# Celesteela
# Eternatus

# %% [markdown]
# We see that the tallest pokemon is Alolan Exeggutor which is folloewd by Steelix, Mega Steelix, Wailord and Primal Kyogre. The newly added Eternatus is number 8th in the list.
#
# The heaviest pokemon is Mega Metagross which is followed by Groudon, Primal Groudon, Mudsdale and Cosmoem. I was definitely not expecting Mudsdale in this list. Another surprise is that Kyogre is taller than Groudon while Groudon is heavier than Kyogre. I imagined the other way around was true.
#
# Now let's check the distribution of height and weight of pokemon to see what is the average height and weight of a pokemon.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")

ax= sns.distplot(df_mega['height_m'], color="y")
ax.set(xlabel='Height in meters')
# Out:
# [Text(0.5, 0, 'Height in meters')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")

ax= sns.distplot(df_mega['weight_kg'], color="r")
ax.set(xlabel='Weigth in kg')
# Out:
# [Text(0.5, 0, 'Weigth in kg')]

# %% [markdown]
# This scatterplot shows the relationship between Attack and Defence stat of a pokemon.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")
X=df['attack']
Y=df['defense']
ax = sns.scatterplot(x=X, y=Y, data=df,  
                     hue=df['is_legendary'], 
                     alpha=.9, palette="muted")
ax.set(xlabel='Attack stat', ylabel='Defense stat')
# Out:
# [Text(0, 0.5, 'Defense stat'), Text(0.5, 0, 'Attack stat')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")
X=df['attack']
Y=df['defense']
ax = sns.scatterplot(x=X, y=Y, data=df,  
                     hue=df['is_mythical'], 
                     alpha=.9, palette="muted")
ax.set(xlabel='Attack stat', ylabel='Defense stat')
# Out:
# [Text(0, 0.5, 'Defense stat'), Text(0.5, 0, 'Attack stat')]

# %% [markdown]
# We see a positive relationship between attack stat and defence stat. This means a strong physical attacker is also a good physical defender. Leggendaries and mythicals tend to do better on this.
#
# Now let us find the pokemon with highest attack and defence stats.

# %%
print("The pokemon with highest attack stat are:")
tall=df['name'][df['attack']>175].tolist()
for i in tall:
    print(i)

print("\nThe pokemon with highest defense stat are:")
heavy=df['name'][df['defense']>200].tolist()
for i in heavy:
    print(i)
# Out:
# The pokemon with highest attack stat are:
# Primal Groudon
# DeoxysAttack Forme
# Kartana
#
# The pokemon with highest defense stat are:
# Shuckle
# Stakataka

# %% [markdown]
# The pokemon with highest attack stat are Primal Groudon followed by Deoxys Attack Forme and Kartana.
#
# The pokemon with highest defense stat is Shuckle which is followed by the gen 7 ultra beast Stakataka.

# %%
print("The pokemon with highest attack stat are:")
tall=df_mega['name'][df_mega['attack']>175].tolist()
for i in tall:
    print(i)

print("\nThe pokemon with highest defense stat are:")
heavy=df_mega['name'][df_mega['defense']>200].tolist()
for i in heavy:
    print(i)
# Out:
# The pokemon with highest attack stat are:
# Mega Mewtwo X
# Mega Heracross
# Primal Groudon
# Mega Rayquaza
# DeoxysAttack Forme
# Kartana
#
# The pokemon with highest defense stat are:
# Mega Steelix
# Shuckle
# Mega Aggron
# Stakataka

# %% [markdown]
# If we also add mega evolutions to our list, we can see that the pokemon with highest attack stat is Mega Mewtwo X followed by Mega Heracross, Primal Groudon, Mega Rayquaza, Deoxys Attack Forme and Kartana.
#
# The pokemon with highest defence stat is Mega Steelix, Shuckle, Mega Aggron and Stakataka. Little Shuckle managed to come in top 3 even in a list choke full of megas, legendaries, mythical and all other strong pokemon.

# %% [markdown]
# We do this sctterplot relationship again to find the relationship between special attack and special defense.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")
X=df['sp_attack']
Y=df['sp_defense']
ax = sns.scatterplot(x=X, y=Y, data=df,  
                     hue=df['is_legendary'], 
                     alpha=.9, palette="muted")
ax.set(xlabel='Special Attack stat', ylabel='Special Defence stat')
# Out:
# [Text(0, 0.5, 'Special Defence stat'), Text(0.5, 0, 'Special Attack stat')]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")
X=df['sp_attack']
Y=df['sp_defense']
ax = sns.scatterplot(x=X, y=Y, data=df,  
                     hue=df['is_mythical'], 
                     alpha=.9, palette="muted")
ax.set(xlabel='Special Attack stat', ylabel='Special Defence stat')
# Out:
# [Text(0, 0.5, 'Special Defence stat'), Text(0.5, 0, 'Special Attack stat')]

# %% [markdown]
# This relationship looks more scattered than the attack-defense relarionship. But the trend still remains the same- good special attack corelates with having good special defense and the legendaries tend to do better on this chart.

# %%
print("The pokemon with highest special attack stat are:")
tall=df['name'][df['sp_attack']>175].tolist()
for i in tall:
    print(i)

print("\nThe pokemon with highest special defense stat are:")
heavy=df['name'][df['sp_defense']>190].tolist()
for i in heavy:
    print(i)
# Out:
# The pokemon with highest special attack stat are:
# Primal Kyogre
# DeoxysAttack Forme
#
# The pokemon with highest special defense stat are:
# Shuckle
# Regice

# %% [markdown]
# The pokemon with highest Special attack is Primal Kyogre followed by Deoxys Attack Forme. The pokemon with highest special defense are Shuckle and Regice. So while Groudon was a stong physical attacker, Kyogre is a strong special attacker.

# %%
print("The pokemon with highest special attack stat are:")
tall=df_mega['name'][df_mega['sp_attack']>175].tolist()
for i in tall:
    print(i)

print("\nThe pokemon with highest special defense stat are:")
heavy=df_mega['name'][df_mega['sp_defense']>190].tolist()
for i in heavy:
    print(i)
# Out:
# The pokemon with highest special attack stat are:
# Mega Mewtwo Y
# Primal Kyogre
# Mega Rayquaza
# DeoxysAttack Forme
#
# The pokemon with highest special defense stat are:
# Shuckle
# Regice

# %% [markdown]
# When we include the mega evolution in this, we can see that the pokemon with highest special attack is Mega Mewtwo Y who is closely followed by Primal Kyogre, Mega Rayquaza and Deoxys Attack Forme. While Mega Mewtwo X was a strong physical attacker, Y is a strong special attacker.
#
# The pokemon with highest special defence are Shuckle and Regice. Shuckle looks like a perfect tank with the defences challenging even the legendaries.

# %% [markdown]
# Now we see the distribution of speed among the pokemon.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")

ax= sns.distplot(df_mega['speed'], color="g")
ax.set(xlabel='Speed')
# Out:
# [Text(0.5, 0, 'Speed')]

# %% [markdown]
# To get a better insight, we classify pokemon based on their stanadard deviations from the mean.

# %%
mean= df_mega['speed'].describe()[1]
sd= df_mega['speed'].describe()[2]
fast_pokemon=[]
slow_pokemon=[]
very_fast_pokemon=[]
very_slow_pokemon=[]
normal_pokemon=[]
for i in df_mega.index:
    if(df_mega.speed[i]>mean+(2*sd)):
        very_fast_pokemon.append(df_mega['name'][i])
    elif(df_mega.speed[i]<mean-(2*sd)):
        very_slow_pokemon.append(df_mega['name'][i])
    elif(df_mega.speed[i]>mean+sd):
         fast_pokemon.append(df_mega['name'][i])
    elif(df_mega.speed[i]<mean-sd):
         slow_pokemon.append(df_mega['name'][i])
    else:
         normal_pokemon.append(df_mega['name'][i])
speed_levels=['fast','slow','very fast',
              'very slow' ,'normal']
speed_count = [len(fast_pokemon), len(slow_pokemon), len(very_fast_pokemon)
               ,len(very_slow_pokemon),len(normal_pokemon)]
plt.bar(speed_levels,speed_count)
plt.show()

# %% [markdown]
# We can see that most of the pokemon lie in the normal category which was expected and the overall speed graph seem to be left skewed ie: there are more slower pokemon than faster ones but there are more extremely fast ones as compared to extremely slow ones. This means the slope is very high at the right side of the graph while the graoh seems to be flatter at the right.

# %%
print('Fastest Pokemon: {}'.format(df_mega.name[df_mega['speed'].idxmax()] ))
print('Slowest Pokemon: {}'.format(df_mega.name[df_mega['speed'].idxmin()] ))
# Out:
# Fastest Pokemon: Deoxys Speed Forme
# Slowest Pokemon: Shuckle

# %% [markdown]
# The fastest pokemon is Deoxys Speed Forme while the slowest is shuckle. It was expected from a perfect wall like shuckle.

# %% [markdown]
# Now we see the distribution of hp among the pokemon.

# %%
fig, ax = plt.subplots()
fig.set_size_inches(11.7, 8.27)
sns.set_style("white")

ax= sns.distplot(df_mega['hp'], color="b")
ax.set(xlabel='HP')
# Out:
# [Text(0.5, 0, 'HP')]

# %% [markdown]
# In this graph we classify pokemon based on their hp so that we can understand the distribution better.

# %%
mean= df_mega['hp'].describe()[1]
sd= df_mega['hp'].describe()[2]
bulky=[]
weak=[]
tank=[]
fragile=[]
normal_pokemon=[]
for i in df_mega.index:
    if(df_mega.speed[i]>mean+(2*sd)):
        tank.append(df_mega['name'][i])
    elif(df_mega.speed[i]<mean-(2*sd)):
        fragile.append(df_mega['name'][i])
    elif(df_mega.speed[i]>mean+sd):
         bulky.append(df_mega['name'][i])
    elif(df_mega.speed[i]<mean-sd):
         weak.append(df_mega['name'][i])
    else:
         normal_pokemon.append(df_mega['name'][i])
hp_levels=['bulky','weak','tank',
              'fragile' ,'normal']
hp_count = [len(bulky), len(weak), len(tank),len(fragile),
               len(normal_pokemon)]
plt.bar(hp_levels,hp_count)
plt.show()

# %% [markdown]
# We see that this one is even more left skewed with more pokemon on the waeker side. The bulky ones are definitely less than the weak defense.

# %%
print('The tankiest Pokemon: {}'.format(df_mega.name[df_mega['hp'].idxmax()] ))
print('The most fragile Pokemon: {}'.format(df_mega.name[df_mega['hp'].idxmin()] ))
# Out:
# The tankiest Pokemon: Blissey
# The most fragile Pokemon: Shedinja

# %% [markdown]
# The tankiest pokemon is Blissey and the pokemon with least defense is Shedinja. Shedinja has only 1 hp.

# %% [markdown]
# Now let us see how many pokemon are introduced in each generation.

# %%
ax = sns.countplot(x="generation", data=df)

# %% [markdown]
# This most pokemon were introduced in the 5th generation followed by 1st generation. The lowest number of pokemon were revealed in 6th gen.

# %% [markdown]
# Now let us see how many pokemon are legendary and how many are mythical out of the

# %%
leg=0
non_leg=0
mythical=0
        for i in df.index:
    if df['is_legendary'][i]==1:
        leg+=1
    elif df['is_mythical'][i]==1:
        mythical+=1
    else:
        non_leg+=1
labels="non-legendary", "legendary", "mythical"
sizes=[non_leg, leg, mythical]
explode=(0,0.1,0.1)
plt.pie(sizes, labels=labels, explode=explode,autopct='%1.1f%%',shadow=True,
        startangle=90)
plt.axis('equal')
plt.title('Legendary vs Mythical vs Non-legendary pokemon')
plt.tight_layout()
plt.show()

# %% [markdown]
# Now let us see how many legendaries and mythicals were revealed in all the generations

# %%
f, ax = plt.subplots(figsize=(8, 8))
ax = sns.countplot(x="generation", hue ='is_legendary', data=df )

# %%
f, ax = plt.subplots(figsize=(8, 8))
ax = sns.countplot(x="generation", hue ='is_mythical', data=df )

# %% [markdown]
# We can see that most legendaries and mythicals were revealed in 5th, 7th and 4th generation. The least were revealed in first generation. As of now there is no mythical pokemon from 8th generation. The new games will have some new mythicals.

# %% [markdown]
# Now let us see the number of mega evolution forms revealed from each generation.

# %%
f, ax = plt.subplots(figsize=(8, 8))
ax = sns.countplot(x="generation", hue ='is_mega', data=df_mega)

# %% [markdown]
# We see that most 3rd gen mons have have mega evolution which makes sense because Ruby and Sapphire got remakes in the year those mega evolutions were introduced. It is surprising that gen 6 has such a low numbe of mons considering the fact that this is the generatiion in which mega evolution was introduced. After 6th gen, we never got to see any new megas.

# %%
Now let us see the corelation between different stats to get a better understanding of how they are related.
# Out:
#   File "<ipython-input-408-530766d3a701>", line 1
#     Now let us see the corelation between different stats to get a better understanding of how they are related.
#           ^
# SyntaxError: invalid syntax

# %%
corr = df[['hp','attack','sp_attack','defense','sp_defense','speed','base_happiness',  
            'base_egg_steps','capture_rate','is_legendary', 'is_mythical']].corr()
f, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %% [markdown]
# We can see that the capture rate is negatively corelated with almost everything. That is, more the capture rate, the weaker the pokemon will be.
#
# Base happiness also has a negative corelation with all the stats. So a pokemon with less base friendship will generally be on a stronger side.
#
# There are also some corelation between stats like a pokemon with higher defense and special defence is usually slower. special attack and special defense also have a positive corelation.

# %%
corr = df[['capture_rate','base_happiness','base_egg_steps','is_legendary']].corr()
print (corr)
# Out:
#                 capture_rate  base_happiness  base_egg_steps  is_legendary
# capture_rate        1.000000        0.188972       -0.387356     -0.288940
# base_happiness      0.188972        1.000000       -0.562921     -0.410316
# base_egg_steps     -0.387356       -0.562921        1.000000      0.689343
# is_legendary       -0.288940       -0.410316        0.689343      1.000000

# %% [markdown]
# When we closely look at the relation between capture_rate, base_happiness, base_egg_steps and is_legendary we find that is_legendary is highly corelated with base_egg_steps which means that legendary pokemon have higher base_egg_steps. And legendary pokemon have less base happiness.

# %% [markdown]
# Now we look at the most common type of pokemon including dingle and dual types.

# %%
mixed_type =[]
for i, row in df_mega.iterrows():
    if df_mega.type2[i]=="None":
        mixed_type.append(df_mega['type1'][i])
    else:
        mixed_type.append(df_mega['type1'][i]+" "+df_mega['type2'][i])
df_mega['mixed_type']=mixed_type

# %%
df_mega['mixed_type'].value_counts().reset_index(name="count").query("count > 10")["index"]
# Out:
# 0             Water
# 1            Normal
# 2           Psychic
# 3             Grass
# 4              Fire
# 5          Electric
# 6          Fighting
# 7     Normal Flying
# 8               Ice
# 9               Bug
# 10            Fairy
# 11           Ground
# 12           Poison
# 13     Grass Poison
# 14             Rock
# 15            Ghost
# 16       Bug Flying
# 17             Dark
# 18           Dragon
# 19       Bug Poison
# Name: index, dtype: object

# %% [markdown]
# We see that again, water type is the most common type after which comes normal then psychic, grass and fire. The most common dual type is normal flying

# %% [markdown]
# Now in the end we take the aggregate of all the type defences to see which pokemon has the most resistances and which pokemon has the least resistances.

# %%
against_ = ['against_bug', 'against_dark', 'against_dragon', 'against_electric', 'against_fairy', 'against_fighting', 
            'against_fire','against_flying', 'against_ghost', 'against_grass', 'against_ground', 'against_ice', 
            'against_normal','against_poison', 'against_psychic', 'against_rock', 'against_steel', 'against_water']
df_mega['against_aggregate'] = df_mega[against_].sum(axis=1)
df_mega['against_mean'] = df_mega[against_].mean(axis=1)

# %%
against_unique = df_mega['against_mean'].unique().tolist()
high = min(against_unique)
low  = max(against_unique)

print ('The pokemon with most resistance to other types')
print (df_mega.name[df_mega['against_mean'] == high])
print ('The pokemon with least resistance to other types')
print (df_mega.name[df_mega['against_mean'] == low])
# Out:
# The pokemon with most resistance to other types
# 341    Shedinja
# Name: name, dtype: object
# The pokemon with least resistance to other types
# 800     Amaura
# 801    Aurorus
# Name: name, dtype: object

# %% [markdown]
# The pokemon with most resistances is shedinja while the pokemon with least resistances is the gen 6th pokemon Amaura line.
